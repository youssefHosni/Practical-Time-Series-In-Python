# %% [markdown]
# <a href="https://colab.research.google.com/github/youssefHosni/Time-Series-With-Python/blob/main/Arima%20Models%20in%20Python/ARIMA_Models_In%C2%A0Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the important libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. ARMA Models

# %% [markdown]
# ## 1.1. Introduction to stationarity

# %%
# Load in the time series
candy = pd.read_csv('candy_production.csv', 
            index_col='date',
            parse_dates=True)
# change the plot style into fivethirtyeight 
plt.style.use('fivethirtyeight')

# Plot and show the time series on axis ax1
fig, ax1 = plt.subplots()
candy.plot(ax=ax1, figsize=(12,10))
plt.title('Monthly production of candy in US')
plt.xlabel('Date')
plt.ylabel('Production')
plt.show()

# %%
# Split the data into a train and test set
candy_train = candy.loc[:'2006']
candy_test = candy.loc['2007':]

# Create an axis
fig, ax = plt.subplots()

# Plot the train and test sets on the axis ax
candy_train.plot(ax=ax, figsize=(12,10))
candy_test.plot(ax=ax)
plt.title('train - test split of the monthly production of candy in US')
plt.xlabel('Date')
plt.ylabel('Production')
plt.show()

# %% [markdown]
# ## 1.2. Making a time series stationary

# %%
from statsmodels.tsa.stattools import adfuller
results = adfuller(candy)
print(results)
# Out:
# (-1.7760153075016107, 0.3924327500714, 14, 549, {'1%': -3.4423174665535385, '5%': -2.866818952732754, '10%': -2.569581505602171}, 3094.828881317046)

# %%
# Calculate the first difference and drop the nans
candy_diff = candy.diff()
candy_diff = candy_diff.dropna()

# Run test and print
result_diff = adfuller(candy_diff)
print(result_diff)
# Out:
# (-6.175912489755653, 6.631549159335702e-08, 13, 549, {'1%': -3.4423174665535385, '5%': -2.866818952732754, '10%': -2.569581505602171}, 3091.3123583091397)

# %%
earthquake = pd.read_csv('earthquakes.csv',
                         index_col='date',
                        parse_dates=True)

# %%
# Calculate log-return and drop nans
earthquake_log = np.log(earthquake)
earthquake_log = earthquake_log.dropna()

# Run test and print
result_log = adfuller(earthquake_log['earthquakes_per_year'])
print(result_log)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27656/2118200788.py in <module>
#       4
#       5 # Run test and print
# ----> 6 result_log = adfuller(earthquake_log['earthquakes_per_year'])
#       7 print(result_log)
#
# NameError: name 'adfuller' is not defined

# %% [markdown]
# ## 1.3. Introduction to AR, MA adn ARMA models

# %%
from statsmodels.tsa.arima_process import arma_generate_sample
ar_coefs = [1, -0.5] 
ma_coefs = [1, 0.2]
y = arma_generate_sample(ar_coefs, ma_coefs, nsample=100, scale=0.5)

# %%
from statsmodels.tsa.arima.model import ARIMA
# Instantiate model object
model = ARIMA(y, order=(1,0,1))
# Fit model
results = model.fit()
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# # 2. Fitting the Future

# %% [markdown]
# ## 2.1. Fitting time series models

# %%
from statsmodels.tsa.arima.model import ARIMA
# Instantiate model object
model = ARIMA(y, order=(1,0,1))
# Fit model
results = model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 -66.653
# Date:                Mon, 11 Apr 2022   AIC                            141.305
# Time:                        04:29:13   BIC                            151.726
# Sample:                             0   HQIC                           145.523
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1195      0.145      0.827      0.408      -0.164       0.403
# ar.L1          0.6481      0.114      5.668      0.000       0.424       0.872
# ma.L1          0.0802      0.159      0.503      0.615      -0.232       0.393
# sigma2         0.2206      0.031      7.060      0.000       0.159       0.282
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.07
# Prob(Q):                              0.92   Prob(JB):                         0.97
# Heteroskedasticity (H):               1.07   Skew:                             0.05
# Prob(H) (two-sided):                  0.86   Kurtosis:                         3.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ## 2.2. Forecasting

# %%
amazon = pd.read_csv('amazon_close.csv',
                     index_col='date',
                     parse_dates=True)
amazon.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
results = adfuller(amazon)
print(results)
# Out:
# (-1.3446690965326022, 0.6084966311408393, 23, 1235, {'1%': -3.4356560275160835, '5%': -2.8638831211270817, '10%': -2.568017509711682}, 10782.877783880944)

# %%
# Instantiate the model
model = ARIMA(amazon, order=(1,1,1))

# Fit the model
results = model.fit()

# Print model fit summary
print(results.summary())
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   inferred_freq = False
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   inferred_freq = False
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   inferred_freq = False
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   inferred_freq = False
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   inferred_freq = False
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   inferred_freq = False
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1259
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5538.450
# Date:                Mon, 11 Apr 2022   AIC                          11082.901
# Time:                        06:49:45   BIC                          11098.312
# Sample:                             0   HQIC                         11088.693
#                                - 1259
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8065      0.104      7.726      0.000       0.602       1.011
# ma.L1         -0.8352      0.099     -8.450      0.000      -1.029      -0.641
# sigma2       390.4373      5.974     65.352      0.000     378.728     402.147
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              7318.62
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.06   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Generate predictions
one_step_forecast = results.get_prediction(end=20)

# Extract prediction mean
mean_forecast = one_step_forecast.predicted_mean

# Get confidence intervals of  predictions
confidence_intervals = one_step_forecast.conf_int()

# Select lower and upper confidence limits
lower_limits = confidence_intervals.loc[:,'lower close']
upper_limits = confidence_intervals.loc[:,'upper close']

# Print best estimate  predictions
print(mean_forecast)
# Out:
# date
# 2019-02-08       0.000000
# 2019-02-07    1588.203390
# 2019-02-06    1613.657085
# 2019-02-05    1638.957978
# 2019-02-04    1657.209111
# 2019-02-01    1632.688779
# 2019-01-31    1625.911319
# 2019-01-30    1715.839389
# 2019-01-29    1669.391489
# 2019-01-28    1595.197449
# 2019-01-25    1637.732122
# 2019-01-24    1669.502851
# 2019-01-23    1654.486721
# 2019-01-22    1640.077085
# 2019-01-18    1632.442740
# 2019-01-17    1694.591530
# 2019-01-16    1691.962059
# 2019-01-15    1683.000154
# 2019-01-14    1674.173180
# 2019-01-11    1618.532405
# 2019-01-10    1640.994516
# Name: predicted_mean, dtype: float64

# %%
mean_forecast = mean_forecast[1:]

# %%
mean_forecast
# Out:
# date
# 2019-02-07    1588.203390
# 2019-02-06    1613.657085
# 2019-02-05    1638.957978
# 2019-02-04    1657.209111
# 2019-02-01    1632.688779
# 2019-01-31    1625.911319
# 2019-01-30    1715.839389
# 2019-01-29    1669.391489
# 2019-01-28    1595.197449
# 2019-01-25    1637.732122
# 2019-01-24    1669.502851
# 2019-01-23    1654.486721
# 2019-01-22    1640.077085
# 2019-01-18    1632.442740
# 2019-01-17    1694.591530
# 2019-01-16    1691.962059
# 2019-01-15    1683.000154
# 2019-01-14    1674.173180
# 2019-01-11    1618.532405
# 2019-01-10    1640.994516
# Name: predicted_mean, dtype: float64

# %%
# plot the amazon data
plt.plot(amazon.index, amazon, label='observed')

# plot your mean predictions
plt.plot(mean_forecast.index,mean_forecast,color='r', label='forecast')

# shade the area between your confidence limits
plt.fill_between(lower_limits.index, lower_limits, upper_limits, color='pink')

# set labels, legends and show plot
plt.xlabel('Date')
plt.ylabel('Amazon Stock Price - Close USD')
plt.legend()
plt.show()

# %%
# Generate predictions
dynamic_forecast = results.get_prediction(end= 20, dynamic=True)

# Extract prediction mean
mean_forecast = dynamic_forecast.predicted_mean

# Get confidence intervals of predictions
confidence_intervals = dynamic_forecast.conf_int()

# Select lower and upper confidence limits
lower_limits = confidence_intervals.loc[:,'lower close']
upper_limits = confidence_intervals.loc[:,'upper close']

# Print best estimate predictions
print(mean_forecast)
# Out:
# date
# 2019-02-08    0.0
# 2019-02-07    0.0
# 2019-02-06    0.0
# 2019-02-05    0.0
# 2019-02-04    0.0
# 2019-02-01    0.0
# 2019-01-31    0.0
# 2019-01-30    0.0
# 2019-01-29    0.0
# 2019-01-28    0.0
# 2019-01-25    0.0
# 2019-01-24    0.0
# 2019-01-23    0.0
# 2019-01-22    0.0
# 2019-01-18    0.0
# 2019-01-17    0.0
# 2019-01-16    0.0
# 2019-01-15    0.0
# 2019-01-14    0.0
# 2019-01-11    0.0
# 2019-01-10    0.0
# Name: predicted_mean, dtype: float64

# %%
# plot the amazon data
plt.plot(amazon.index, amazon, label='observed')

# plot your mean forecast
plt.plot(mean_forecast.index, mean_forecast, color='r', label='forecast')

# shade the area between your confidence limits
plt.fill_between(lower_limits.index, lower_limits, 
         upper_limits, color='pink')

# set labels, legends and show plot
plt.xlabel('Date')
plt.ylabel('Amazon Stock Price - Close USD')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.3. ARIMA models for non-stationary time series

# %%
amazon = pd.read_csv('amazon_close.csv',
                     index_col='date',
                     parse_dates=True)
amazon.plot()
plt.title('Amazon stock price change with time')
plt.ylabel('Stock price')
# Out:
# Text(0, 0.5, 'Stock price')

# %%
from statsmodels.tsa.stattools import adfuller

# Run Dicky-Fuller test
result = adfuller(amazon)

# Print test statistic
print('The test stastics:', result[0])

# Print p-value
print("The p-value:",result[1])
# Out:
# The test stastics: -1.3446690965326022
# The p-value: 0.6084966311408393

# %% [markdown]
# The data is not stationary and we have to take a tranform of it.

# %%
# take the first diff
amazon_diff = amazon.diff()
amazon_diff.dropna(inplace=True)

# Run Dicky-Fuller test
result = adfuller(amazon_diff)

# Print test statistic
print('The test stastics:', result[0])

# Print p-value
print("The p-value:",result[1])
# Out:
# The test stastics: -7.203579488811234
# The p-value: 2.331271725487324e-10

# %% [markdown]
# The p-value is less than 0.05, therefore the data is stationary

# %%
from statsmodels.tsa.arima.model import ARIMA
# Instantiate model object
model = ARIMA(amazon_diff, order=(1,0,1))
# Fit model
results = model.fit()
print(results.summary())
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1258
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -5536.175
# Date:                Sat, 07 May 2022   AIC                          11080.350
# Time:                        16:25:04   BIC                          11100.900
# Sample:                             0   HQIC                         11088.073
#                                - 1258
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.9877      0.457     -2.160      0.031      -1.884      -0.092
# ar.L1          0.8267      0.078     10.556      0.000       0.673       0.980
# ma.L1         -0.8603      0.072    -11.866      0.000      -1.002      -0.718
# sigma2       389.0144      5.935     65.547      0.000     377.382     400.647
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7308.89
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.06   Skew:                             0.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from statsmodels.tsa.arima.model import ARIMA
# Instantiate model object
model = ARIMA(amazon, order=(1,1,1))
# Fit model
results = model.fit()
print(results.summary())
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1259
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5538.450
# Date:                Sat, 07 May 2022   AIC                          11082.901
# Time:                        16:27:30   BIC                          11098.312
# Sample:                             0   HQIC                         11088.693
#                                - 1259
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8065      0.104      7.726      0.000       0.602       1.011
# ma.L1         -0.8352      0.099     -8.450      0.000      -1.029      -0.641
# sigma2       390.4373      5.974     65.352      0.000     378.728     402.147
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              7318.62
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.06   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # 3. Finding the Best Models

# %% [markdown]
# ## 3.1. Introduction to ACF and PACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Make ACF plot
plot_acf(earthquake['earthquakes_per_year'], lags=10, zero=False)
plt.show()

# %%
# Make PACF plot
plot_pacf(earthquake['earthquakes_per_year'], lags=10, zero=False)
plt.show()

# %% [markdown]
# ## 3.2. Intro to AIC and BIC

# %%
import statsmodels.api as sm
order_aic_bic =[]

# Loop over p values from 0-2
for p in range(3):
    # Loop over q values from 0-2
    for q in range(3):
      
        try:
            # create and fit ARMA(p,q) model
            model = sm.tsa.statespace.SARIMAX(earthquake['earthquakes_per_year'], order=(p, 0, q))
            results = model.fit()
            
            # Print order and results
            order_aic_bic.append((p, q, results.aic, results.bic))            
        except:
            print(p, q, None, None)
            
# Make DataFrame of model order and AIC/BIC scores
order_df = pd.DataFrame(order_aic_bic, columns=['p', 'q', 'aic','bic'])

# lets sort them by AIC and BIC

# Sort by AIC
print("Models sorted by AIC ")
print("\n")
print(order_df.sort_values('aic').reset_index(drop=True))

# Sort by BIC
print("Models sorted by BIC ")
print("\n")
print(order_df.sort_values('bic').reset_index(drop=True))
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# Models sorted by AIC
#
#
#    p  q         aic         bic
# 0  1  1  647.132300  654.917660
# 1  1  2  648.738566  659.119046
# 2  2  1  648.842840  659.223319
# 3  2  2  648.850644  661.826244
# 4  2  0  656.028374  663.813734
# 5  1  0  666.645526  671.835765
# 6  0  2  761.067479  768.852838
# 7  0  1  799.674173  804.864412
# 8  0  0  888.429772  891.024892
# Models sorted by BIC
#
#
#    p  q         aic         bic
# 0  1  1  647.132300  654.917660
# 1  1  2  648.738566  659.119046
# 2  2  1  648.842840  659.223319
# 3  2  2  648.850644  661.826244
# 4  2  0  656.028374  663.813734
# 5  1  0  666.645526  671.835765
# 6  0  2  761.067479  768.852838
# 7  0  1  799.674173  804.864412
# 8  0  0  888.429772  891.024892

# %% [markdown]
# ## 3.3. The model diagnostic

# %%
# The model with the best p and q found from pervious step
model = sm.tsa.statespace.SARIMAX(earthquake['earthquakes_per_year'], order=(1, 0, 1))
# Fit model
results = model.fit()
# Assign residuals to variable
residuals = results.resid
print(residuals)
# Out:
# date
# 1900-01-01    13.000000
# 1901-01-01     1.857276
# 1902-01-01    -5.045721
# 1903-01-01    -0.527074
# 1904-01-01     5.821641
#                 ...
# 1994-01-01    -0.589256
# 1995-01-01     9.835545
# 1996-01-01     2.694023
# 1997-01-01    -0.278098
# 1998-01-01    -3.939243
# Length: 99, dtype: float64
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
# The mean absolute error
mae = np.mean(np.abs(residuals))
print(mae)
# Out:
# 4.755625670994196

# %%
# Create the 4 diagostics plots
results.plot_diagnostics(figsize=(10,10))
plt.show()
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
# Summary statistics
print(results.summary())
# Out:
#                                 SARIMAX Results
# ================================================================================
# Dep. Variable:     earthquakes_per_year   No. Observations:                   99
# Model:                 SARIMAX(1, 0, 1)   Log Likelihood                -320.566
# Date:                  Sat, 30 Apr 2022   AIC                            647.132
# Time:                          06:41:12   BIC                            654.918
# Sample:                      01-01-1900   HQIC                           650.282
#                            - 01-01-1998
# Covariance Type:                    opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9893      0.014     70.282      0.000       0.962       1.017
# ma.L1         -0.5517      0.089     -6.198      0.000      -0.726      -0.377
# sigma2        37.0254      4.980      7.434      0.000      27.264      46.787
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                 2.76
# Prob(Q):                              0.83   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.64   Skew:                             0.38
# Prob(H) (two-sided):                  0.20   Kurtosis:                         3.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # 3.4. The Box-Jenkins method

# %% [markdown]
# ## Identification

# %%
co2 = pd.read_csv('co2.csv',
                     index_col='date',
                     parse_dates=True)
co2.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from statsmodels.tsa.stattools import adfuller

# Run Dicky-Fuller test
result = adfuller(co2)

# Print test statistic
print('The test stastics:', result[0])

# Print p-value
print("The p-value:",result[1])
# Out:
# The test stastics: 4.774866785205469
# The p-value: 1.0

# %%
co2_diff = co2.diff()
co2_diff = co2_diff.dropna()
co2_diff.plot()

# Run Dicky-Fuller test
result_diff = adfuller(co2_diff)

# Print test statistic
print('The test stastics:', result_diff[0])

# Print p-value
print("The p-value:",result_diff[1])
# Out:
# The test stastics: -5.287425631615265
# The p-value: 5.813789175332468e-06

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Create figure
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(12,8))
 
# Plot the ACF of savings on ax1
plot_acf(co2_diff, lags=20, zero=False, ax=ax1)

# Plot the PACF of savings on ax2
plot_pacf(co2_diff, lags=20, zero=False, ax=ax2)

plt.show()

# %% [markdown]
# # Estimation

# %%
import statsmodels.api as sm
order_aic_bic =[]

# Loop over p values from 0-4
for p in range(5):
    # Loop over q values from 0-4
    for q in range(5):
      
        try:
            # create and fit ARMA(p,q) model
            model = sm.tsa.statespace.SARIMAX(co2, order=(p, 1, q))
            results = model.fit()
            
            # Print order and results
            order_aic_bic.append((p, q, results.aic, results.bic))            
        except:
            print(p, q, None, None)
            
# Make DataFrame of model order and AIC/BIC scores
order_df = pd.DataFrame(order_aic_bic, columns=['p', 'q', 'aic','bic'])

# lets sort them by AIC and BIC

# Sort by AIC
print("Models sorted by AIC ")
print("\n")
print(order_df.sort_values('aic').reset_index(drop=True))

# Sort by BIC
print("Models sorted by BIC ")
print("\n")
print(order_df.sort_values('bic').reset_index(drop=True))
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# 3 3 None None
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# Models sorted by AIC
#
#
#     p  q          aic          bic
# 0   4  4   921.814711   963.102661
# 1   2  4  1297.058431  1329.171281
# 2   3  4  1300.818700  1337.519100
# 3   2  3  1525.544582  1553.069882
# 4   2  1  1526.197900  1544.548100
# 5   4  3  1526.885758  1563.586158
# 6   2  2  1528.164866  1551.102616
# 7   3  1  1528.165664  1551.103414
# 8   3  2  1529.270778  1556.796078
# 9   1  4  1594.276525  1621.801825
# 10  4  2  1602.576938  1634.689789
# 11  3  0  1609.487338  1627.837538
# 12  4  0  1610.223137  1633.160887
# 13  4  1  1611.723967  1639.249267
# 14  0  3  1658.731030  1677.081230
# 15  0  4  1658.815935  1681.753685
# 16  1  3  1659.882416  1682.820166
# 17  2  0  1680.120665  1693.883315
# 18  1  2  1707.772491  1726.122691
# 19  0  2  1756.145317  1769.907968
# 20  1  1  1776.533722  1790.296372
# 21  1  0  1870.432865  1879.607965
# 22  0  1  1932.012001  1941.187102
# 23  0  0  2367.846163  2372.433713
# Models sorted by BIC
#
#
#     p  q          aic          bic
# 0   4  4   921.814711   963.102661
# 1   2  4  1297.058431  1329.171281
# 2   3  4  1300.818700  1337.519100
# 3   2  1  1526.197900  1544.548100
# 4   2  2  1528.164866  1551.102616
# 5   3  1  1528.165664  1551.103414
# 6   2  3  1525.544582  1553.069882
# 7   3  2  1529.270778  1556.796078
# 8   4  3  1526.885758  1563.586158
# 9   1  4  1594.276525  1621.801825
# 10  3  0  1609.487338  1627.837538
# 11  4  0  1610.223137  1633.160887
# 12  4  2  1602.576938  1634.689789
# 13  4  1  1611.723967  1639.249267
# 14  0  3  1658.731030  1677.081230
# 15  0  4  1658.815935  1681.753685
# 16  1  3  1659.882416  1682.820166
# 17  2  0  1680.120665  1693.883315
# 18  1  2  1707.772491  1726.122691
# 19  0  2  1756.145317  1769.907968
# 20  1  1  1776.533722  1790.296372
# 21  1  0  1870.432865  1879.607965
# 22  0  1  1932.012001  1941.187102
# 23  0  0  2367.846163  2372.433713
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Create and fit model
model = sm.tsa.statespace.SARIMAX(co2, order=(4,1,4), trend='c')
results = model.fit()

# Create the 4 diagostics plots
results.plot_diagnostics(figsize=(10,10))
plt.show()

# Print summary
print(results.summary())
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                CO2_ppm   No. Observations:                  727
# Model:               SARIMAX(4, 1, 4)   Log Likelihood                -443.681
# Date:                Sun, 01 May 2022   AIC                            907.362
# Time:                        13:47:48   BIC                            953.237
# Sample:                    03-01-1958   HQIC                           925.065
#                          - 09-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0329      0.002     19.033      0.000       0.030       0.036
# ar.L1          2.6643      0.031     86.813      0.000       2.604       2.724
# ar.L2         -3.4936      0.074    -47.326      0.000      -3.638      -3.349
# ar.L3          2.4470      0.074     33.155      0.000       2.302       2.592
# ar.L4         -0.8716      0.031    -28.442      0.000      -0.932      -0.812
# ma.L1         -2.7000      0.075    -36.234      0.000      -2.846      -2.554
# ma.L2          3.1680      0.185     17.104      0.000       2.805       3.531
# ma.L3         -1.9052      0.183    -10.406      0.000      -2.264      -1.546
# ma.L4          0.5051      0.071      7.120      0.000       0.366       0.644
# sigma2         0.2280      0.017     13.623      0.000       0.195       0.261
# ===================================================================================
# Ljung-Box (L1) (Q):                   7.38   Jarque-Bera (JB):                 7.01
# Prob(Q):                              0.01   Prob(JB):                         0.03
# Heteroskedasticity (H):               1.10   Skew:                             0.12
# Prob(H) (two-sided):                  0.46   Kurtosis:                         3.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # 4. Seasonal ARIMA Models

# %% [markdown]
# ## 4.1. Seasonal time series

# %%
# load the candy production data
candy = pd.read_csv('candy_production.csv', 
            index_col='date',
            parse_dates=True)

# Plot and show the time series on axis ax1
fig, ax1 = plt.subplots()
candy.plot(ax=ax1, figsize=(12,10))
plt.title('Monthly production of candy in US')
plt.xlabel('Date')
plt.ylabel('Production')
plt.show()

# %%
# Import
from statsmodels.tsa.seasonal import seasonal_decompose
# Decompose data
decomp_results = seasonal_decompose(candy, period=12)

# Plot decomposed data
plt.rcParams["figure.figsize"] = (10,15)
decomp_results.plot()
plt.show()

# %%
# Subtract long rolling average over 5 steps
candy = candy - candy.rolling(5).mean()
# Drop NaN values
candy = candy.dropna()

# Identifying seasonal data using ACF

# Create figure
fig, ax = plt.subplots(1,1, figsize=(8,4))
# Plot ACF
plot_acf(candy.dropna(), ax=ax, lags=25, zero=False)
plt.show()

# %% [markdown]
# ## 4.2. Seasonal ARIMA model

# %%
# load the candy production data
candy = pd.read_csv('candy_production.csv', 
            index_col='date',
            parse_dates=True)

# Plot and show the time series on axis ax1
fig, ax1 = plt.subplots()
candy.plot(ax=ax1, figsize=(12,10))
plt.title('Monthly production of candy in US')
plt.xlabel('Date')
plt.ylabel('Production')
plt.show()

# %%
# Seasonal differencing
S = 12
candy_diff = candy.diff(S)
candy_diff.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# one step differencing
candy_diff = candy.diff()
candy_diff = candy_diff.dropna()
candy_diff.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Run Dicky-Fuller test
result = adfuller(candy_diff)

# Print test statistic
print('The test stastics:', result[0])

# Print p-value
print("The p-value:",result[1])
# Out:
# The test stastics: -6.175912489755653
# The p-value: 6.631549159335702e-08

# %%
# find the non-seasonal model prameters 

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Create figure
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(12,8))
 
# Plot the ACF of savings on ax1
plot_acf(candy_diff, lags=20, zero=False, ax=ax1)

# Plot the PACF of savings on ax2
plot_pacf(candy_diff, lags=20, zero=False, ax=ax2)

plt.show()

# %% [markdown]
# We cannot estimate the values of the non-seasonal from the PACF and ACF plot, so we will use AIC and BIC

# %%
import statsmodels.api as sm
order_aic_bic =[]

# Loop over p values from 0-4
for p in range(5):
    # Loop over q values from 0-4
    for q in range(5):
      
        try:
            # create and fit ARMA(p,q) model
            model = sm.tsa.statespace.SARIMAX(candy_diff, order=(p, 1, q))
            results = model.fit()
            
            # Print order and results
            order_aic_bic.append((p, q, results.aic, results.bic))            
        except:
            print(p, q, None, None)
            
# Make DataFrame of model order and AIC/BIC scores
order_df = pd.DataFrame(order_aic_bic, columns=['p', 'q', 'aic','bic'])

# lets sort them by AIC and BIC

# Sort by AIC
print("Models sorted by AIC ")
print("\n")
print(order_df.sort_values('aic').reset_index(drop=True))

# Sort by BIC
print("Models sorted by BIC ")
print("\n")
print(order_df.sort_values('bic').reset_index(drop=True))
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# Models sorted by AIC
#
#
#     p  q          aic          bic
# 0   4  3  3763.241823  3797.893837
# 1   3  3  3790.184356  3820.504869
# 2   3  2  3828.004550  3853.993561
# 3   3  4  3860.040604  3894.692619
# 4   4  2  3906.153917  3936.474430
# 5   4  4  3915.960221  3954.943737
# 6   1  4  3924.795150  3950.784161
# 7   2  3  3928.222339  3954.211350
# 8   2  2  3929.496813  3951.154322
# 9   1  3  3933.187639  3954.845149
# 10  4  1  3956.500055  3982.489066
# 11  3  1  3959.913131  3981.570640
# 12  2  4  3983.082090  4013.402603
# 13  0  4  3989.834419  4011.491928
# 14  0  3  3992.917585  4010.243592
# 15  2  1  4027.123518  4044.449526
# 16  0  2  4041.131180  4054.125686
# 17  0  1  4068.134320  4076.797324
# 18  1  2  4079.301579  4096.627587
# 19  4  0  4121.805669  4143.463178
# 20  3  0  4132.107316  4149.433323
# 21  1  1  4163.968651  4176.963157
# 22  1  0  4166.429943  4175.092946
# 23  2  0  4167.954663  4180.949169
# 24  0  0  4279.442303  4283.773804
# Models sorted by BIC
#
#
#     p  q          aic          bic
# 0   4  3  3763.241823  3797.893837
# 1   3  3  3790.184356  3820.504869
# 2   3  2  3828.004550  3853.993561
# 3   3  4  3860.040604  3894.692619
# 4   4  2  3906.153917  3936.474430
# 5   1  4  3924.795150  3950.784161
# 6   2  2  3929.496813  3951.154322
# 7   2  3  3928.222339  3954.211350
# 8   1  3  3933.187639  3954.845149
# 9   4  4  3915.960221  3954.943737
# 10  3  1  3959.913131  3981.570640
# 11  4  1  3956.500055  3982.489066
# 12  0  3  3992.917585  4010.243592
# 13  0  4  3989.834419  4011.491928
# 14  2  4  3983.082090  4013.402603
# 15  2  1  4027.123518  4044.449526
# 16  0  2  4041.131180  4054.125686
# 17  0  1  4068.134320  4076.797324
# 18  1  2  4079.301579  4096.627587
# 19  4  0  4121.805669  4143.463178
# 20  3  0  4132.107316  4149.433323
# 21  1  0  4166.429943  4175.092946
# 22  1  1  4163.968651  4176.963157
# 23  2  0  4167.954663  4180.949169
# 24  0  0  4279.442303  4283.773804
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# The best prameters to be used is (4,3)

# %%
# Plotting seasonal ACF and PACF

# Create figure
fig, (ax1, ax2) = plt.subplots(2,1)

# Plot seasonal ACF
plot_acf(candy_diff, lags=[12,24,36,48,60,72, 84, 96 ], ax=ax1)

# Plot seasonal PACF
plot_pacf(candy_diff, lags=[12,24,36,48,60,72, 84, 96], ax=ax2)
plt.show()

# %% [markdown]
# ACF tails offf and PACF cuts off after lag of 3

# %%
# Fitting a SARIMA model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Instantiate model
S = 12
D = 1
d = 1
P = 0
Q = 3
p = 4
q = 3
model = SARIMAX(candy, order=(p,d,q), seasonal_order=(P,D,Q,S))

# Fit model
results = model.fit()
# Out:
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ## 4.3. Automation and saving

# %%
# Searching over model orders
import pmdarima as pm

results = pm.auto_arima(candy)
print(results)
print(results.summary())
results.plot_diagnostics()
# Out:
#  ARIMA(2,1,3)(0,0,0)[0]
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  564
# Model:               SARIMAX(2, 1, 3)   Log Likelihood               -1860.785
# Date:                Tue, 03 May 2022   AIC                           3733.570
# Time:                        12:17:23   BIC                           3759.570
# Sample:                             0   HQIC                          3743.720
#                                 - 564
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.7056      0.011    160.814      0.000       1.685       1.726
# ar.L2         -0.9692      0.012    -83.805      0.000      -0.992      -0.947
# ma.L1         -1.9864      0.041    -48.177      0.000      -2.067      -1.906
# ma.L2          1.2847      0.079     16.276      0.000       1.130       1.439
# ma.L3         -0.2043      0.044     -4.687      0.000      -0.290      -0.119
# sigma2        43.1480      2.242     19.248      0.000      38.754      47.542
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.44   Jarque-Bera (JB):               107.29
# Prob(Q):                              0.51   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.42   Skew:                             0.36
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
# Seasonal search parameters

results = pm.auto_arima(candy, # data
                        seasonal=True, # is the time series seasonal
                        m=12, # the seasonal period
                        D=1, # seasonal difference order
                        start_P=1, # initial guess for P
                        start_Q=1, # initial guess for Q
                        max_P=4, # max value of P to test
                        max_Q=4, # max value of Q to test
                        information_criterion='aic', # used to select best model
                        trace=True, # print results whilst training
                        error_action='ignore', # ignore orders that don't work
                        stepwise=True,
                       )
print(results)
print(results.summary())
results.plot_diagnostics()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=3033.673, Time=8.39 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=3660.455, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=3135.647, Time=1.71 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=3329.958, Time=1.55 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=3666.283, Time=0.08 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=3040.097, Time=4.72 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=3106.790, Time=6.34 sec
#  ARIMA(2,0,2)(2,1,1)[12] intercept   : AIC=3035.064, Time=16.51 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=3035.337, Time=21.52 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=inf, Time=1.68 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=3033.345, Time=14.54 sec
#  ARIMA(2,0,2)(0,1,3)[12] intercept   : AIC=3035.330, Time=27.59 sec
#  ARIMA(2,0,2)(1,1,3)[12] intercept   : AIC=3037.309, Time=38.58 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=3034.631, Time=7.53 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=3035.067, Time=9.94 sec
#  ARIMA(3,0,2)(0,1,2)[12] intercept   : AIC=3033.376, Time=22.88 sec
#  ARIMA(2,0,3)(0,1,2)[12] intercept   : AIC=3033.706, Time=18.09 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=3037.858, Time=5.23 sec
#  ARIMA(1,0,3)(0,1,2)[12] intercept   : AIC=3036.199, Time=9.21 sec
#  ARIMA(3,0,1)(0,1,2)[12] intercept   : AIC=3035.205, Time=11.28 sec
#  ARIMA(3,0,3)(0,1,2)[12] intercept   : AIC=3011.477, Time=28.22 sec
#  ARIMA(3,0,3)(0,1,1)[12] intercept   : AIC=3010.739, Time=13.56 sec
#  ARIMA(3,0,3)(0,1,0)[12] intercept   : AIC=inf, Time=5.22 sec
#  ARIMA(3,0,3)(1,1,1)[12] intercept   : AIC=3010.529, Time=14.65 sec
#  ARIMA(3,0,3)(1,1,0)[12] intercept   : AIC=3077.659, Time=12.38 sec
#  ARIMA(3,0,3)(2,1,1)[12] intercept   : AIC=3012.355, Time=33.19 sec
#  ARIMA(3,0,3)(1,1,2)[12] intercept   : AIC=3013.643, Time=32.00 sec
#  ARIMA(3,0,3)(2,1,0)[12] intercept   : AIC=3041.046, Time=29.22 sec
#  ARIMA(3,0,3)(2,1,2)[12] intercept   : AIC=3015.170, Time=33.14 sec
#  ARIMA(2,0,3)(1,1,1)[12] intercept   : AIC=3034.053, Time=11.42 sec
#  ARIMA(3,0,2)(1,1,1)[12] intercept   : AIC=3033.807, Time=11.06 sec
#  ARIMA(4,0,3)(1,1,1)[12] intercept   : AIC=3008.535, Time=14.05 sec
#  ARIMA(4,0,3)(0,1,1)[12] intercept   : AIC=3007.646, Time=13.19 sec
#  ARIMA(4,0,3)(0,1,0)[12] intercept   : AIC=3176.688, Time=5.64 sec
#  ARIMA(4,0,3)(0,1,2)[12] intercept   : AIC=3008.696, Time=28.76 sec
#  ARIMA(4,0,3)(1,1,0)[12] intercept   : AIC=3080.995, Time=13.23 sec
#  ARIMA(4,0,3)(1,1,2)[12] intercept   : AIC=3010.543, Time=32.32 sec
#  ARIMA(4,0,2)(0,1,1)[12] intercept   : AIC=3014.431, Time=13.23 sec
#  ARIMA(5,0,3)(0,1,1)[12] intercept   : AIC=3008.611, Time=14.95 sec
#  ARIMA(4,0,4)(0,1,1)[12] intercept   : AIC=inf, Time=16.08 sec
#  ARIMA(3,0,2)(0,1,1)[12] intercept   : AIC=3041.308, Time=5.45 sec
#  ARIMA(3,0,4)(0,1,1)[12] intercept   : AIC=3015.574, Time=16.85 sec
#  ARIMA(5,0,2)(0,1,1)[12] intercept   : AIC=3011.175, Time=14.35 sec
#  ARIMA(5,0,4)(0,1,1)[12] intercept   : AIC=3011.986, Time=18.51 sec
#  ARIMA(4,0,3)(0,1,1)[12]             : AIC=3007.270, Time=9.57 sec
#  ARIMA(4,0,3)(0,1,0)[12]             : AIC=3176.502, Time=4.37 sec
#  ARIMA(4,0,3)(1,1,1)[12]             : AIC=3008.643, Time=12.47 sec
#  ARIMA(4,0,3)(0,1,2)[12]             : AIC=3008.198, Time=24.24 sec
#  ARIMA(4,0,3)(1,1,0)[12]             : AIC=3080.141, Time=8.81 sec
#  ARIMA(4,0,3)(1,1,2)[12]             : AIC=3010.429, Time=26.55 sec
#  ARIMA(3,0,3)(0,1,1)[12]             : AIC=3010.680, Time=9.92 sec
#  ARIMA(4,0,2)(0,1,1)[12]             : AIC=3014.157, Time=8.77 sec
#  ARIMA(5,0,3)(0,1,1)[12]             : AIC=3008.527, Time=12.23 sec
#  ARIMA(4,0,4)(0,1,1)[12]             : AIC=inf, Time=14.63 sec
#  ARIMA(3,0,2)(0,1,1)[12]             : AIC=3042.003, Time=4.02 sec
#  ARIMA(3,0,4)(0,1,1)[12]             : AIC=3015.653, Time=11.59 sec
#  ARIMA(5,0,2)(0,1,1)[12]             : AIC=3012.616, Time=10.93 sec
#  ARIMA(5,0,4)(0,1,1)[12]             : AIC=3011.797, Time=13.64 sec
#
# Best model:  ARIMA(4,0,3)(0,1,1)[12]
# Total fit time: 829.962 seconds
#  ARIMA(4,0,3)(0,1,1)[12]
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  564
# Model:             SARIMAX(4, 0, 3)x(0, 1, [1], 12)   Log Likelihood               -1494.635
# Date:                              Tue, 03 May 2022   AIC                           3007.270
# Time:                                      13:21:23   BIC                           3046.092
# Sample:                                           0   HQIC                          3022.438
#                                               - 564
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4041      0.104      3.880      0.000       0.200       0.608
# ar.L2          0.2342      0.026      9.083      0.000       0.184       0.285
# ar.L3          0.8856      0.018     50.112      0.000       0.851       0.920
# ar.L4         -0.5590      0.097     -5.791      0.000      -0.748      -0.370
# ma.L1          0.3320      0.082      4.057      0.000       0.172       0.492
# ma.L2          0.0358      0.091      0.392      0.695      -0.143       0.215
# ma.L3         -0.7741      0.077    -10.012      0.000      -0.926      -0.623
# ma.S.L12      -0.7054      0.032    -22.043      0.000      -0.768      -0.643
# sigma2        12.9833      0.687     18.889      0.000      11.636      14.330
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):                41.67
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                            -0.38
# Prob(H) (two-sided):                  0.19   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\youss\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
#Saving model objects
# Import joblib
import joblib
# Select a filepath
filepath = 'model.pkl'
# Save model to filepath
joblib.dump(results, filepath)

# Load the model 
# Select a filepath
filepath ='model.pkl'
# Load model object from filepath
loaded_model = joblib.load(filepath)
# Out:
# ['model.pkl']

# %% [markdown]
# ## 4.4. SARIMA and Box-Jenkins
